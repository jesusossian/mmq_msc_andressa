# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
url_file=f"result/lsr_std_math.txt"

df = pd.read_csv(url_file,header=None, sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['instance','rf','time_rf','fop','time_fop']
table['time_total'] = table['time_rf']+table['time_fop']

table_math = table
table_math
# Out:
#        instance       rf  time_rf      fop  time_fop  time_total
# 0      52_1.txt   8915.4     0.49   8751.6      0.73        1.22
# 1      52_2.txt   8908.0     0.49   8852.8      0.94        1.43
# 2      52_3.txt   8648.6     0.46   8631.4      0.56        1.02
# 3      52_4.txt   9227.0     0.51   9076.6      0.96        1.47
# 4      52_5.txt   9758.5     0.57   9758.5      0.88        1.45
# ..          ...      ...      ...      ...       ...         ...
# 103  52_104.txt  39973.5     0.20  38400.0      0.20        0.40
# 104  52_105.txt  40533.0     0.19  39099.8      0.20        0.39
# 105  52_106.txt  45220.6     0.22  41933.6      0.21        0.43
# 106  52_107.txt  39315.8     0.19  38988.2      0.19        0.38
# 107  52_108.txt  43407.2     0.22  40813.2      0.20        0.42
#
# [108 rows x 6 columns]

# %%
latex_table_math = table_math.to_latex(
    index=False,  # To not include the DataFrame index as a column in the table
    caption="Solução viável encontrada pela matheuristica RF+FOP",  # The caption to appear above the table in the LaTeX document
    label="tab:sol_viavel_rf_fop",  # A label used for referencing the table within the LaTeX document
    position="htbp",  # The preferred positions where the table should be placed in the document ('here', 'top', 'bottom', 'page')
    column_format="lrrrrr",  # The format of the columns: left-aligend first column and center-aligned remaining columns as per APA guidelines
    escape=False,  # Disable escaping LaTeX special characters in the DataFrame
    float_format="{:0.2f}".format  # Formats floats to two decimal places
)

print(latex_table_math)
# Out:
# \begin{table}[htbp]
# \caption{Solução viável encontrada pela matheuristica RF+FOP}
# \label{tab:sol_viavel_rf_fop}
# \begin{tabular}{lrrrrr}
# \toprule
# instance & rf & time_rf & fop & time_fop & time_total \\
# \midrule
# 52_1.txt & 8915.40 & 0.49 & 8751.60 & 0.73 & 1.22 \\
# 52_2.txt & 8908.00 & 0.49 & 8852.80 & 0.94 & 1.43 \\
# 52_3.txt & 8648.60 & 0.46 & 8631.40 & 0.56 & 1.02 \\
# 52_4.txt & 9227.00 & 0.51 & 9076.60 & 0.96 & 1.47 \\
# 52_5.txt & 9758.50 & 0.57 & 9758.50 & 0.88 & 1.45 \\
# 52_6.txt & 10308.00 & 0.56 & 10101.50 & 1.12 & 1.68 \\
# 52_7.txt & 9695.50 & 0.50 & 9662.50 & 0.86 & 1.36 \\
# 52_8.txt & 10096.50 & 0.55 & 10080.00 & 0.97 & 1.52 \\
# 52_9.txt & 10312.00 & 0.53 & 10306.40 & 0.84 & 1.37 \\
# 52_10.txt & 11198.60 & 0.54 & 10952.00 & 0.88 & 1.42 \\
# 52_11.txt & 10422.60 & 0.59 & 10422.60 & 0.94 & 1.53 \\
# 52_12.txt & 10793.00 & 0.55 & 10773.60 & 0.98 & 1.53 \\
# 52_13.txt & 13664.60 & 0.30 & 13369.00 & 0.33 & 0.63 \\
# ...

# %%
print(table_math['time_total'].max())
print(table_math['time_total'].mean())
# Out:
# 1.6800000000000002
# 0.6518518518518519

# %%
url_file=f"result/lsr_std_mip_feasible_first.txt"

df = pd.read_csv(url_file,header=None, sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['instance','objval0','bound0','gap0','time0','nodes0','opt0']

table_first_feasible = table
table_first_feasible = table_first_feasible[['instance','objval0','time0']]
table_first_feasible
# Out:
#        instance   objval0  time0
# 0      52_1.txt   12770.8    0.0
# 1      52_2.txt   12827.8    0.0
# 2      52_3.txt   13398.0    0.0
# 3      52_4.txt   13413.4    0.0
# 4      52_5.txt   13936.5    0.0
# ..          ...       ...    ...
# 103  52_104.txt  119959.5    0.0
# 104  52_105.txt  129011.2    0.0
# 105  52_106.txt  118980.0    0.0
# 106  52_107.txt  128970.4    0.0
# 107  52_108.txt  119152.0    0.0
#
# [108 rows x 3 columns]

# %%
latex_table = table_first_feasible.to_latex(
    index=False,  # To not include the DataFrame index as a column in the table
    caption="Primeira solução viável encontrada pelo solver",  # The caption to appear above the table in the LaTeX document
    label="tab:primeiro_sol_viavel",  # A label used for referencing the table within the LaTeX document
    position="htbp",  # The preferred positions where the table should be placed in the document ('here', 'top', 'bottom', 'page')
    column_format="lrr",  # The format of the columns: left-aligend first column and center-aligned remaining columns as per APA guidelines
    escape=False,  # Disable escaping LaTeX special characters in the DataFrame
    float_format="{:0.2f}".format  # Formats floats to two decimal places
)

print(latex_table)
# Out:
# \begin{table}[htbp]
# \caption{Primeira solução viável encontrada pelo solver}
# \label{tab:primeiro_sol_viavel}
# \begin{tabular}{lrr}
# \toprule
# instance & objval0 & time0 \\
# \midrule
# 52_1.txt & 12770.80 & 0.00 \\
# 52_2.txt & 12827.80 & 0.00 \\
# 52_3.txt & 13398.00 & 0.00 \\
# 52_4.txt & 13413.40 & 0.00 \\
# 52_5.txt & 13936.50 & 0.00 \\
# 52_6.txt & 15513.00 & 0.00 \\
# 52_7.txt & 14379.50 & 0.00 \\
# 52_8.txt & 15175.50 & 0.00 \\
# 52_9.txt & 15432.80 & 0.00 \\
# 52_10.txt & 17183.20 & 0.00 \\
# 52_11.txt & 16616.00 & 0.00 \\
# 52_12.txt & 16412.80 & 0.00 \\
# 52_13.txt & 27121.00 & 0.00 \\
# 52_14.txt & 22392.60 & 0.00 \\
# 52_15.txt & 26814.80 & 0.00 \\
# 52_16.txt & 22833.20 & 0.00 \\
# 52_17.txt & 27831.50 & 0.00 \\
# 52_18.txt & 23954.50 & 0.00 \\
# 52_19.txt & 28477.00 & 0.00 \\
# 52_20.txt & 24170.00 & 0.00 \\
# 52_21.txt & 29276.00 & 0.00 \\
# 52_22.txt & 24865.60 & 0.00 \\
# 52_23.txt & 29559.40 & 0.00 \\
# 52_24.txt & 27899.20 & 0.00 \\
# ...

# %%
url_file=f"result/lsr_std_mip_feasible_tmax.txt"

df = pd.read_csv(url_file,header=None, sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['instance','objval1','bound1','gap1','time1','nodes1','opt1']

table_feasible_tmax = table
table_feasible_tmax
# Out:
#        instance  objval1    bound1  gap1  time1   nodes1  opt1
# 0      52_1.txt   8710.2   2904.49  0.67   1.68  28593.0     0
# 1      52_2.txt   8929.6   2665.34  0.70   1.68  27264.0     0
# 2      52_3.txt   8842.8   2710.63  0.69   1.68  26465.0     0
# 3      52_4.txt   9305.6   2737.65  0.71   1.68  28149.0     0
# 4      52_5.txt  10006.0   2969.79  0.70   1.68  27089.0     0
# ..          ...      ...       ...   ...    ...      ...   ...
# 103  52_104.txt  37391.5  19482.38  0.48   1.68  32104.0     0
# 104  52_105.txt  39624.0  20100.23  0.49   1.68  32948.0     0
# 105  52_106.txt  41639.0  19966.41  0.52   1.68  34785.0     0
# 106  52_107.txt  39032.0  20923.13  0.46   1.68  34657.0     0
# 107  52_108.txt  41581.6  19460.79  0.53   1.68  34123.0     0
#
# [108 rows x 7 columns]

# %%
latex_table_feasible_tmax = table_feasible_tmax.to_latex(
    index=False,  # To not include the DataFrame index as a column in the table
    caption="Melhor solução viável encontrada pelo solver em TMAX segundos",  # The caption to appear above the table in the LaTeX document
    label="tab:melhor_sol_viavel_tmax",  # A label used for referencing the table within the LaTeX document
    position="htbp",  # The preferred positions where the table should be placed in the document ('here', 'top', 'bottom', 'page')
    column_format="lrrrrrr",  # The format of the columns: left-aligend first column and center-aligned remaining columns as per APA guidelines
    escape=False,  # Disable escaping LaTeX special characters in the DataFrame
    float_format="{:0.2f}".format  # Formats floats to two decimal places
)

print(latex_table_feasible_tmax)
# Out:
# \begin{table}[htbp]
# \caption{Melhor solução viável encontrada pelo solver em TMAX segundos}
# \label{tab:melhor_sol_viavel_tmax}
# \begin{tabular}{lrrrrrr}
# \toprule
# instance & objval1 & bound1 & gap1 & time1 & nodes1 & opt1 \\
# \midrule
# 52_1.txt & 8710.20 & 2904.49 & 0.67 & 1.68 & 28593.00 & 0 \\
# 52_2.txt & 8929.60 & 2665.34 & 0.70 & 1.68 & 27264.00 & 0 \\
# 52_3.txt & 8842.80 & 2710.63 & 0.69 & 1.68 & 26465.00 & 0 \\
# 52_4.txt & 9305.60 & 2737.65 & 0.71 & 1.68 & 28149.00 & 0 \\
# 52_5.txt & 10006.00 & 2969.79 & 0.70 & 1.68 & 27089.00 & 0 \\
# 52_6.txt & 10177.50 & 2785.66 & 0.73 & 1.68 & 29227.00 & 0 \\
# 52_7.txt & 9878.00 & 2972.20 & 0.70 & 1.68 & 24761.00 & 0 \\
# 52_8.txt & 10207.50 & 2866.06 & 0.72 & 1.68 & 29661.00 & 0 \\
# 52_9.txt & 10627.20 & 3066.73 & 0.71 & 1.68 & 29624.00 & 0 \\
# 52_10.txt & 11138.80 & 2990.62 & 0.73 & 1.68 & 26219.00 & 0 \\
# 52_11.txt & 10377.20 & 3067.44 & 0.70 & 1.68 & 27846.00 & 0 \\
# ...

# %%
url_file=f"result/lsr_std_mip_feasible_tmean.txt"

df = pd.read_csv(url_file,header=None, sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['instance','objval2','bound2','gap2','time2','nodes2','opt2']

table_feasible_tmean = table
table_feasible_tmean
# Out:
#        instance  objval2    bound2  gap2  time2   nodes2  opt2
# 0      52_1.txt   8846.8   2678.03  0.70   0.65   9333.0     0
# 1      52_2.txt   9142.2   2461.23  0.73   0.65   9648.0     0
# 2      52_3.txt   8904.2   2481.87  0.72   0.65   8918.0     0
# 3      52_4.txt   9353.2   2537.17  0.73   0.65   9299.0     0
# 4      52_5.txt  10065.0   2721.31  0.73   0.65   9424.0     0
# ..          ...      ...       ...   ...    ...      ...   ...
# 103  52_104.txt  37391.5  18222.04  0.51   0.65   8678.0     0
# 104  52_105.txt  39655.0  18999.20  0.52   0.65  10240.0     0
# 105  52_106.txt  41639.0  18827.12  0.55   0.65  10962.0     0
# 106  52_107.txt  39236.4  19855.53  0.49   0.65  10699.0     0
# 107  52_108.txt  41604.4  18361.96  0.56   0.65  10780.0     0
#
# [108 rows x 7 columns]

# %%
latex_table_feasible_tmean = table_feasible_tmean.to_latex(
    index=False,  # To not include the DataFrame index as a column in the table
    caption="Melhor solução viável encontrada pelo solver em TMEAN segundos",  # The caption to appear above the table in the LaTeX document
    label="tab:melhor_sol_viavel_tmean",  # A label used for referencing the table within the LaTeX document
    position="htbp",  # The preferred positions where the table should be placed in the document ('here', 'top', 'bottom', 'page')
    column_format="lrrrrrr",  # The format of the columns: left-aligend first column and center-aligned remaining columns as per APA guidelines
    escape=False,  # Disable escaping LaTeX special characters in the DataFrame
    float_format="{:0.2f}".format  # Formats floats to two decimal places
)

print(latex_table_feasible_tmean)
# Out:
# \begin{table}[htbp]
# \caption{Melhor solução viável encontrada pelo solver em TMEAN segundos}
# \label{tab:melhor_sol_viavel_tmean}
# \begin{tabular}{lrrrrrr}
# \toprule
# instance & objval2 & bound2 & gap2 & time2 & nodes2 & opt2 \\
# \midrule
# 52_1.txt & 8846.80 & 2678.03 & 0.70 & 0.65 & 9333.00 & 0 \\
# 52_2.txt & 9142.20 & 2461.23 & 0.73 & 0.65 & 9648.00 & 0 \\
# 52_3.txt & 8904.20 & 2481.87 & 0.72 & 0.65 & 8918.00 & 0 \\
# 52_4.txt & 9353.20 & 2537.17 & 0.73 & 0.65 & 9299.00 & 0 \\
# 52_5.txt & 10065.00 & 2721.31 & 0.73 & 0.65 & 9424.00 & 0 \\
# 52_6.txt & 10383.00 & 2577.83 & 0.75 & 0.65 & 10084.00 & 0 \\
# 52_7.txt & 9940.50 & 2777.26 & 0.72 & 0.65 & 9263.00 & 0 \\
# 52_8.txt & 10625.00 & 2627.05 & 0.75 & 0.65 & 10316.00 & 0 \\
# 52_9.txt & 10725.80 & 2816.60 & 0.74 & 0.65 & 9652.00 & 0 \\
# 52_10.txt & 11411.20 & 2793.71 & 0.76 & 0.65 & 10574.00 & 0 \\
# 52_11.txt & 10660.20 & 2824.34 & 0.74 & 0.65 & 10044.00 & 0 \\
# ...

# %%
table_resume = pd.DataFrame()
table_resume['dif0'] = table_math['fop'] - table_first_feasible['objval0']
table_resume['dif2'] = table_math['fop'] - table_feasible_tmean['objval2']
table_resume['dif1'] = table_math['fop'] - table_feasible_tmax['objval1']
table_resume
# Out:
#         dif0    dif2    dif1
# 0    -4019.2   -95.2    41.4
# 1    -3975.0  -289.4   -76.8
# 2    -4766.6  -272.8  -211.4
# 3    -4336.8  -276.6  -229.0
# 4    -4178.0  -306.5  -247.5
# ..       ...     ...     ...
# 103 -81559.5  1008.5  1008.5
# 104 -89911.4  -555.2  -524.2
# 105 -77046.4   294.6   294.6
# 106 -89982.2  -248.2   -43.8
# 107 -78338.8  -791.2  -768.4
#
# [108 rows x 3 columns]

# %%
positive_count_dif1 = (table_resume['dif0'] < 0).sum()
positive_count_dif2 = (table_resume['dif2'] < 0).sum()
positive_count_dif3 = (table_resume['dif1'] < 0).sum()
print(f"Ganho do fop em relacao ao mip first feasible: {positive_count_dif1}")
print(f"Ganho do fop em relacao ao mip first feasible tmean: {positive_count_dif2}")
print(f"Ganho do fop em relacao ao mip first feasible tmax: {positive_count_dif3}")
# Out:
# Ganho do fop em relacao ao mip first feasible: 108
# Ganho do fop em relacao ao mip first feasible tmean: 74
# Ganho do fop em relacao ao mip first feasible tmax: 54

# %%
def tabela_mip(url_file):
    
    df = pd.read_csv(url_file,header=None, sep=';')

    table = pd.DataFrame()
    table = pd.concat([table, df], ignore_index=True)
    table.columns = ['instance','objval','bound','gap','time','nodes','opt']
    table = table[['instance','bound','objval','gap','time','nodes','opt']]

    table['grupo'] = 'grupo' 
   
    table_result = pd.DataFrame()

    contador  = 1
    set_cont = 1
    while True:
        set_ ='set0{}'.format(str(set_cont))
        tab = pd.DataFrame()
        for i in range(contador, contador+12):
            t = table.loc[table['instance'] == f'52_{i}.txt']
            tab = pd.concat([tab,t])
            table.loc[table[table['instance'] == f'52_{i}.txt'].index,'grupo'] = set_
            
        
        tab = pd.DataFrame({
            'instance':f'{set_}',
            'bound':tab['bound'].mean().round(2),
            'objval':tab['objval'].mean().round(2),
            'gap':tab['gap'].mean().round(2),
            'time':tab['time'].mean().round(2),
            'nodes':tab['nodes'].mean().round(2),
            'opt':tab['opt'].sum().round(2),
            },index=[f'std']
        )


        if table_result.shape[0] == 0:
            table_result = tab.copy(deep=True)
        else:
            table_result = pd.concat([table_result,tab])

        contador = contador + 12
        set_cont = set_cont + 1

        if set_cont > 9 :
            break

    return table_result.reset_index(drop=True), table

# %%
def tabela_math(url_file):
    
    df = pd.read_csv(url_file,header=None, sep=';')

    table = pd.DataFrame()
    table = pd.concat([table, df], ignore_index=True)
    table.columns = ['instance','rf','time_rf','fop','time_fop']
    table['time_total'] = table['time_rf']+table['time_fop']

    table['grupo'] = 'grupo' 
   
    table_result = pd.DataFrame()

    contador  = 1
    set_cont = 1
    while True:
        set_ ='set0{}'.format(str(set_cont))
        tab = pd.DataFrame()
        for i in range(contador, contador+12):
            t = table.loc[table['instance'] == f'52_{i}.txt']
            tab = pd.concat([tab,t])
            table.loc[table[table['instance'] == f'52_{i}.txt'].index,'grupo'] = set_
        
        tab = pd.DataFrame({
            'instance':f'{set_}',
            'rf':tab['rf'].mean().round(2),
            'time_rf':tab['time_rf'].mean().round(2),
            'fop':tab['fop'].mean().round(2),
            'time_fop':tab['time_fop'].mean().round(2),
            'time_total':tab['time_total'].mean().round(2)
            },index=[f'std']
        )


        if table_result.shape[0] == 0:
            table_result = tab.copy(deep=True)
        else:
            table_result = pd.concat([table_result,tab])

        contador = contador + 12
        set_cont = set_cont + 1

        if set_cont > 9 :
            break

    return table_result.reset_index(drop=True), table

# %%
file=f"result/lsr_std_mip_feasible_first.txt"

table_first_feasible_set, table_first_feasible_set_ = tabela_mip(file)

# %%
table_first_feasible_set = table_first_feasible_set[['instance','objval','time']]
table_first_feasible_set
# Out:
#   instance     objval  time
# 0    set01   14754.94   0.0
# 1    set02   26266.23   0.0
# 2    set03   81300.89   0.0
# 3    set04   22182.42   0.0
# 4    set05   32648.08   0.0
# 5    set06   88007.67   0.0
# 6    set07   58353.91   0.0
# 7    set08   69422.38   0.0
# 8    set09  122978.48   0.0

# %%
latex_table_first_feasible_set = table_first_feasible_set.to_latex(
    index=False,  # To not include the DataFrame index as a column in the table
    caption="Melhor solução viável encontrada pelo solver",  # The caption to appear above the table in the LaTeX document
    label="tab:melhor_sol_viavel_tmean",  # A label used for referencing the table within the LaTeX document
    position="htbp",  # The preferred positions where the table should be placed in the document ('here', 'top', 'bottom', 'page')
    column_format="lrr",  # The format of the columns: left-aligend first column and center-aligned remaining columns as per APA guidelines
    escape=False,  # Disable escaping LaTeX special characters in the DataFrame
    float_format="{:0.2f}".format  # Formats floats to two decimal places
)

print(latex_table_first_feasible_set)
# Out:
# \begin{table}[htbp]
# \caption{Melhor solução viável encontrada pelo solver}
# \label{tab:melhor_sol_viavel_tmean}
# \begin{tabular}{lrr}
# \toprule
# instance & objval & time \\
# \midrule
# set01 & 14754.94 & 0.00 \\
# set02 & 26266.23 & 0.00 \\
# set03 & 81300.89 & 0.00 \\
# set04 & 22182.42 & 0.00 \\
# set05 & 32648.08 & 0.00 \\
# set06 & 88007.67 & 0.00 \\
# set07 & 58353.91 & 0.00 \\
# set08 & 69422.38 & 0.00 \\
# set09 & 122978.48 & 0.00 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
file=f"result/lsr_std_mip_feasible_tmax.txt"

table_feasible_tmax_set, table_feasible_tmax_set_ = tabela_mip(file)

# %%
table_feasible_tmax_set
# Out:
#   instance     bound    objval   gap  time     nodes  opt
# 0    set01   2892.48   9922.72  0.71  1.68  27745.08    0
# 1    set02   4864.08  13873.39  0.65  1.68  25964.83    0
# 2    set03  13043.70  24885.45  0.48  1.68  25552.00    0
# 3    set04   4606.03  13111.41  0.65  1.68  30005.42    0
# 4    set05   6131.10  17333.38  0.64  1.68  30811.92    0
# 5    set06  14290.37  28307.64  0.49  1.68  27246.50    0
# 6    set07  11550.27  20438.18  0.43  1.68  31210.08    0
# 7    set08  12843.74  25014.90  0.49  1.68  32393.92    0
# 8    set09  19246.84  37127.57  0.48  1.68  31872.25    0

# %%
latex_table_feasible_tmax_set = table_feasible_tmax_set.to_latex(
    index=False,  # To not include the DataFrame index as a column in the table
    caption="Melhor solução viável encontrada pelo solver em TMAX segundos",  # The caption to appear above the table in the LaTeX document
    label="tab:melhor_sol_viavel_tmax",  # A label used for referencing the table within the LaTeX document
    position="htbp",  # The preferred positions where the table should be placed in the document ('here', 'top', 'bottom', 'page')
    column_format="lrrrrrr",  # The format of the columns: left-aligend first column and center-aligned remaining columns as per APA guidelines
    escape=False,  # Disable escaping LaTeX special characters in the DataFrame
    float_format="{:0.2f}".format  # Formats floats to two decimal places
)

print(latex_table_feasible_tmax_set)
# Out:
# \begin{table}[htbp]
# \caption{Melhor solução viável encontrada pelo solver em TMAX segundos}
# \label{tab:melhor_sol_viavel_tmax}
# \begin{tabular}{lrrrrrr}
# \toprule
# instance & bound & objval & gap & time & nodes & opt \\
# \midrule
# set01 & 2892.48 & 9922.72 & 0.71 & 1.68 & 27745.08 & 0 \\
# set02 & 4864.08 & 13873.39 & 0.65 & 1.68 & 25964.83 & 0 \\
# set03 & 13043.70 & 24885.45 & 0.48 & 1.68 & 25552.00 & 0 \\
# set04 & 4606.03 & 13111.41 & 0.65 & 1.68 & 30005.42 & 0 \\
# set05 & 6131.10 & 17333.38 & 0.64 & 1.68 & 30811.92 & 0 \\
# set06 & 14290.37 & 28307.64 & 0.49 & 1.68 & 27246.50 & 0 \\
# set07 & 11550.27 & 20438.18 & 0.43 & 1.68 & 31210.08 & 0 \\
# set08 & 12843.74 & 25014.90 & 0.49 & 1.68 & 32393.92 & 0 \\
# set09 & 19246.84 & 37127.57 & 0.48 & 1.68 & 31872.25 & 0 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
file=f"result/lsr_std_mip_feasible_tmean.txt"

table_feasible_tmean_set, table_feasible_tmean_set_ = tabela_mip(file)

table_feasible_tmean_set
# Out:
#   instance     bound    objval   gap  time    nodes  opt
# 0    set01   2672.18  10093.11  0.74  0.65  9780.08    0
# 1    set02   4457.50  13965.78  0.68  0.65  8740.58    0
# 2    set03  11920.46  25093.47  0.53  0.65  8350.58    0
# 3    set04   4257.10  13270.47  0.68  0.65  9030.25    0
# 4    set05   5683.68  17507.64  0.68  0.65  9517.17    0
# 5    set06  13244.69  28544.02  0.54  0.65  8968.92    0
# 6    set07  10490.24  20525.81  0.48  0.65  8602.17    0
# 7    set08  11809.15  25148.85  0.53  0.65  8943.08    0
# 8    set09  18123.23  37220.49  0.51  0.65  9590.00    0

# %%
latex_table_feasible_tmean_set = table_feasible_tmean_set.to_latex(
    index=False,  # To not include the DataFrame index as a column in the table
    caption="Melhor solução viável encontrada pelo solver em TMEAN segundos",  # The caption to appear above the table in the LaTeX document
    label="tab:melhor_sol_viavel_tmean",  # A label used for referencing the table within the LaTeX document
    position="htbp",  # The preferred positions where the table should be placed in the document ('here', 'top', 'bottom', 'page')
    column_format="lrrrrrr",  # The format of the columns: left-aligend first column and center-aligned remaining columns as per APA guidelines
    escape=False,  # Disable escaping LaTeX special characters in the DataFrame
    float_format="{:0.2f}".format  # Formats floats to two decimal places
)

print(latex_table_feasible_tmean_set)
# Out:
# \begin{table}[htbp]
# \caption{Melhor solução viável encontrada pelo solver em TMEAN segundos}
# \label{tab:melhor_sol_viavel_tmean}
# \begin{tabular}{lrrrrrr}
# \toprule
# instance & bound & objval & gap & time & nodes & opt \\
# \midrule
# set01 & 2672.18 & 10093.11 & 0.74 & 0.65 & 9780.08 & 0 \\
# set02 & 4457.50 & 13965.78 & 0.68 & 0.65 & 8740.58 & 0 \\
# set03 & 11920.46 & 25093.47 & 0.53 & 0.65 & 8350.58 & 0 \\
# set04 & 4257.10 & 13270.47 & 0.68 & 0.65 & 9030.25 & 0 \\
# set05 & 5683.68 & 17507.64 & 0.68 & 0.65 & 9517.17 & 0 \\
# set06 & 13244.69 & 28544.02 & 0.54 & 0.65 & 8968.92 & 0 \\
# set07 & 10490.24 & 20525.81 & 0.48 & 0.65 & 8602.17 & 0 \\
# set08 & 11809.15 & 25148.85 & 0.53 & 0.65 & 8943.08 & 0 \\
# set09 & 18123.23 & 37220.49 & 0.51 & 0.65 & 9590.00 & 0 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
file=f"result/lsr_std_math.txt"

table_math_set, table_math_set_ = tabela_math(file)

# %%
table_math_set
# Out:
#   instance        rf  time_rf       fop  time_fop  time_total
# 0    set01   9856.98     0.53   9780.79      0.89        1.42
# 1    set02  13979.71     0.32  13671.12      0.41        0.73
# 2    set03  26252.88     0.21  25008.06      0.16        0.37
# 3    set04  13128.09     0.36  13009.17      0.49        0.85
# 4    set05  17366.63     0.34  17100.82      0.51        0.85
# 5    set06  29714.86     0.22  28358.95      0.17        0.39
# 6    set07  21004.72     0.21  20639.34      0.21        0.42
# 7    set08  25575.98     0.21  25174.50      0.25        0.45
# 8    set09  39140.93     0.19  37463.98      0.18        0.37

# %%
latex_table_math_set = table_math_set.to_latex(
    index=False,  # To not include the DataFrame index as a column in the table
    caption="Solução viável encontrada pelo RF+FOP",  # The caption to appear above the table in the LaTeX document
    label="tab:sol_math",  # A label used for referencing the table within the LaTeX document
    position="htbp",  # The preferred positions where the table should be placed in the document ('here', 'top', 'bottom', 'page')
    column_format="lrrrrrr",  # The format of the columns: left-aligend first column and center-aligned remaining columns as per APA guidelines
    escape=False,  # Disable escaping LaTeX special characters in the DataFrame
    float_format="{:0.2f}".format  # Formats floats to two decimal places
)

print(latex_table_math_set)
# Out:
# \begin{table}[htbp]
# \caption{Solução viável encontrada pelo RF+FOP}
# \label{tab:sol_math}
# \begin{tabular}{lrrrrrr}
# \toprule
# instance & rf & time_rf & fop & time_fop & time_total \\
# \midrule
# set01 & 9856.98 & 0.53 & 9780.79 & 0.89 & 1.42 \\
# set02 & 13979.71 & 0.32 & 13671.12 & 0.41 & 0.73 \\
# set03 & 26252.88 & 0.21 & 25008.06 & 0.16 & 0.37 \\
# set04 & 13128.09 & 0.36 & 13009.17 & 0.49 & 0.85 \\
# set05 & 17366.63 & 0.34 & 17100.82 & 0.51 & 0.85 \\
# set06 & 29714.86 & 0.22 & 28358.95 & 0.17 & 0.39 \\
# set07 & 21004.72 & 0.21 & 20639.34 & 0.21 & 0.42 \\
# set08 & 25575.98 & 0.21 & 25174.50 & 0.25 & 0.45 \\
# set09 & 39140.93 & 0.19 & 37463.98 & 0.18 & 0.37 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
file=f"result/lsr_std_mip.txt"

table_mip_set, table_mip_set_ = tabela_mip(file)
table_mip_set
# Out:
#   instance     bound    objval  gap    time      nodes  opt
# 0    set01   9674.50   9680.20  0.0  419.51  723210.67   11
# 1    set02  13530.83  13530.83  0.0  161.10  281019.25   12
# 2    set03  24430.29  24430.29  0.0   19.24   25153.83   12
# 3    set04  12843.64  12843.64  0.0   10.76   21227.25   12
# 4    set05  16826.48  16826.48  0.0  123.93  226197.33   12
# 5    set06  27706.90  27706.90  0.0   35.28   43102.75   12
# 6    set07  20334.82  20334.82  0.0    1.41    1795.92   12
# 7    set08  24661.75  24661.75  0.0    2.18    2259.50   12
# 8    set09  36360.38  36360.38  0.0    4.40    3224.17   12

# %%
latex_table_mip_set = table_mip_set.to_latex(
    index=False,  # To not include the DataFrame index as a column in the table
    caption="Soluções encontradas pelo solver",  # The caption to appear above the table in the LaTeX document
    label="tab:sol_mip",  # A label used for referencing the table within the LaTeX document
    position="htbp",  # The preferred positions where the table should be placed in the document ('here', 'top', 'bottom', 'page')
    column_format="lrrrrrr",  # The format of the columns: left-aligend first column and center-aligned remaining columns as per APA guidelines
    escape=False,  # Disable escaping LaTeX special characters in the DataFrame
    float_format="{:0.2f}".format  # Formats floats to two decimal places
)

print(latex_table_mip_set)
# Out:
# \begin{table}[htbp]
# \caption{Soluções encontradas pelo solver}
# \label{tab:sol_mip}
# \begin{tabular}{lrrrrrr}
# \toprule
# instance & bound & objval & gap & time & nodes & opt \\
# \midrule
# set01 & 9674.50 & 9680.20 & 0.00 & 419.51 & 723210.67 & 11 \\
# set02 & 13530.83 & 13530.83 & 0.00 & 161.10 & 281019.25 & 12 \\
# set03 & 24430.29 & 24430.29 & 0.00 & 19.24 & 25153.83 & 12 \\
# set04 & 12843.64 & 12843.64 & 0.00 & 10.76 & 21227.25 & 12 \\
# set05 & 16826.48 & 16826.48 & 0.00 & 123.93 & 226197.33 & 12 \\
# set06 & 27706.90 & 27706.90 & 0.00 & 35.28 & 43102.75 & 12 \\
# set07 & 20334.82 & 20334.82 & 0.00 & 1.41 & 1795.92 & 12 \\
# set08 & 24661.75 & 24661.75 & 0.00 & 2.18 & 2259.50 & 12 \\
# set09 & 36360.38 & 36360.38 & 0.00 & 4.40 & 3224.17 & 12 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
file=f"result/lsr_std_mip.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

tab = pd.DataFrame()
tab = pd.concat([tab, df], ignore_index=True)
tab.columns = ['instance','bound','objval','gap','time','nodes','opt']

resume = pd.DataFrame({
    'instance':f'resume',
    'bound':tab['bound'].mean().round(2),
    'objval':tab['objval'].mean().round(2),
    'gap':tab['gap'].mean().round(2),
    'time':tab['time'].mean().round(2),
    'nodes':tab['nodes'].mean().round(2),
    'opt':tab['opt'].sum().round(2),
    },index=["resume"]
)

tab = pd.concat([tab, resume], ignore_index=True)

tab_mip = tab
tab_mip
# Out:
#        instance     bound    objval  gap    time      nodes  opt
# 0      52_1.txt   8698.80   8698.80  0.0   12.09   20827.00    1
# 1      52_2.txt   8781.80   8781.80  0.0   35.71   92569.00    1
# 2      52_3.txt   8541.60   8541.60  0.0    4.37    8093.00    1
# 3      52_4.txt   8943.80   8943.80  0.0   36.89   95366.00    1
# 4      52_5.txt   9717.00   9717.00  0.0  201.02  392059.00    1
# ..          ...       ...       ...  ...     ...        ...  ...
# 104  52_105.txt  38622.80  38622.80  0.0    4.66    3592.00    1
# 105  52_106.txt  40310.40  40310.40  0.0   10.80    8824.00    1
# 106  52_107.txt  38611.20  38611.20  0.0    5.00    4076.00    1
# 107  52_108.txt  39826.20  39826.20  0.0    3.25    2114.00    1
# 108      resume  20708.37  20707.73  0.0   86.42  147465.63  107
#
# [109 rows x 7 columns]

# %%
set_ = 'set01'

tab = pd.DataFrame()
for i in range(1,13):
    t = tab_mip.loc[tab_mip['instance'] == f'52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'bound':tab['bound'].mean(),
    'objval':tab['objval'].mean(),
    'gap':tab['gap'].mean(),
    'time':tab['time'].mean(),
    'nodes':tab['nodes'].mean(),
    'opt':tab['opt'].sum(),
    },index=[f'set01']
)

set01_mip = tab
#set01_mip

# %%
set_ = 'set02'

tab = pd.DataFrame()
for i in range(13,25):
    t = tab_mip.loc[tab_mip['instance'] == f'52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'bound':tab['bound'].mean(),
    'objval':tab['objval'].mean(),
    'gap':tab['gap'].mean(),
    'time':tab['time'].mean(),
    'nodes':tab['nodes'].mean(),
    'opt':tab['opt'].sum(),
    },index=[f'set02']
)

set02_mip = tab
#set02_mip

# %%
set_ = 'set03'

tab = pd.DataFrame()
for i in range(25,37):
    t = tab_mip.loc[tab_mip['instance'] == f'52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'bound':tab['bound'].mean(),
    'objval':tab['objval'].mean(),
    'gap':tab['gap'].mean(),
    'time':tab['time'].mean(),
    'nodes':tab['nodes'].mean(),
    'opt':tab['opt'].sum(),
    },index=[f'set03']
)

set03_mip = tab
#set03_mip

# %%
set_ = 'set04'

tab = pd.DataFrame()
for i in range(37,49):
    t = tab_mip.loc[tab_mip['instance'] == f'52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'bound':tab['bound'].mean(),
    'objval':tab['objval'].mean(),
    'gap':tab['gap'].mean(),
    'time':tab['time'].mean(),
    'nodes':tab['nodes'].mean(),
    'opt':tab['opt'].sum(),
    },index=[f'set04']
)


set04_mip = tab
#set04_mip

# %%
set_ = 'set05'

tab = pd.DataFrame()
for i in range(49,61):
    t = tab_mip.loc[tab_mip['instance'] == f'52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'bound':tab['bound'].mean(),
    'objval':tab['objval'].mean(),
    'gap':tab['gap'].mean(),
    'time':tab['time'].mean(),
    'nodes':tab['nodes'].mean(),
    'opt':tab['opt'].sum(),
    },index=[f'set05']
)

set05_mip = tab
#set05_mip

# %%
set_ = 'set06'

tab = pd.DataFrame()
for i in range(61,73):
    t = tab_mip.loc[tab_mip['instance'] == f'52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'bound':tab['bound'].mean(),
    'objval':tab['objval'].mean(),
    'gap':tab['gap'].mean(),
    'time':tab['time'].mean(),
    'nodes':tab['nodes'].mean(),
    'opt':tab['opt'].sum(),
    },index=[f'set06']
)

set06_mip = tab
#set06_mip

# %%
set_ = 'set07'

tab = pd.DataFrame()
for i in range(73,85):
    t = tab_mip.loc[tab_mip['instance'] == f'52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'bound':tab['bound'].mean(),
    'objval':tab['objval'].mean(),
    'gap':tab['gap'].mean(),
    'time':tab['time'].mean(),
    'nodes':tab['nodes'].mean(),
    'opt':tab['opt'].sum(),
    },index=[f'set07']
)

set07_mip = tab
#set07_mip

# %%
set_ = 'set08'

tab = pd.DataFrame()
for i in range(85,97):
    t = tab_mip.loc[tab_mip['instance'] == f'52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'bound':tab['bound'].mean(),
    'objval':tab['objval'].mean(),
    'gap':tab['gap'].mean(),
    'time':tab['time'].mean(),
    'nodes':tab['nodes'].mean(),
    'opt':tab['opt'].sum(),
    },index=[f'set08']
)

set08_mip = tab
#set08_mip

# %%
set_ = 'set09'

tab = pd.DataFrame()
for i in range(97,109):
    t = tab_mip.loc[tab_mip['instance'] == f'52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'bound':tab['bound'].mean(),
    'objval':tab['objval'].mean(),
    'gap':tab['gap'].mean(),
    'time':tab['time'].mean(),
    'nodes':tab['nodes'].mean(),
    'opt':tab['opt'].sum(),
    },index=[f'set09']
)

set09_mip = tab
#set09_mip

# %%
res_mip = pd.DataFrame()
res_mip = pd.concat([res_mip,set01_mip], ignore_index= True)
res_mip = pd.concat([res_mip,set02_mip], ignore_index= True)
res_mip = pd.concat([res_mip,set03_mip], ignore_index= True)
res_mip = pd.concat([res_mip,set04_mip], ignore_index= True)
res_mip = pd.concat([res_mip,set05_mip], ignore_index= True)
res_mip = pd.concat([res_mip,set06_mip], ignore_index= True)
res_mip = pd.concat([res_mip,set07_mip], ignore_index= True)
res_mip = pd.concat([res_mip,set08_mip], ignore_index= True)
res_mip = pd.concat([res_mip,set09_mip], ignore_index= True)
#res_mip

# %%
tab = pd.DataFrame({
    'instance':f'res_mip',
    'bound':res_mip['bound'].mean(),
    'objval':res_mip['objval'].mean(),
    'gap':res_mip['gap'].mean(),
    'time':res_mip['time'].mean(),
    'nodes':res_mip['nodes'].mean(),
    'opt':res_mip['opt'].sum(),
    },index=[f'res_mip']
)

res_mip = pd.concat([res_mip, tab], ignore_index=True)
res_mip

#print(res_mip[['instance','objval','bound','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#   instance         bound        objval       gap        time          nodes  \
# 0    set01   9680.200000   9674.500000  0.000833  419.507500  723210.666667
# 1    set02  13530.833333  13530.833333  0.000000  161.103333  281019.250000
# 2    set03  24430.291667  24430.291667  0.000000   19.242500   25153.833333
# 3    set04  12843.641667  12843.641667  0.000000   10.765000   21227.250000
# 4    set05  16826.475000  16826.475000  0.000000  123.930000  226197.333333
# 5    set06  27706.900000  27706.900000  0.000000   35.277500   43102.750000
# 6    set07  20334.816667  20334.816667  0.000000    1.412500    1795.916667
# 7    set08  24661.750000  24661.750000  0.000000    2.180833    2259.500000
# 8    set09  36360.383333  36360.383333  0.000000    4.395833    3224.166667
# 9  res_mip  20708.365741  20707.732407  0.000093   86.423889  147465.629630
#
#    opt
# 0   11
# 1   12
# 2   12
# 3   12
# 4   12
# 5   12
# 6   12
# 7   12
# 8   12
# 9  107
